# %% [markdown]
# ![1*NDQR0S6ZkD4Hb1h1QIUdFQ.png](https://cdn-images-1.medium.com/max/1600/1*NDQR0S6ZkD4Hb1h1QIUdFQ.png  )

# %% [markdown]
# ## Table of Contents
#
# 1. [Problem Statement](#section1)<br>
# 2. [DataSet Loading and Brif Description](#section2)<br>
#     - 2.1 [Variable Notes](#section21)<br>
#     - 2.2 [Data Import](#section22)<br>
# 3. [Examining Data Available From An Existing Information Source-Data profiling](#section3)<br>
#     - 3.1 [Basic DataSet Understanding](#section31)<br>
#     - 3.2 [Pre-Profile](#section32)<br>
#     - 3.3 [Data Preprocessing](#section33)<br>
#         - 3.3.1 [Age NULL Value Replace with Median](#section331)<br>
#         - 3.3.2 [](#section332)<br>
#     - 3.4 [Post  Profiling](#section34)<br>
# 4. [Observation & Questions](#section4)<br>

# %% [markdown]
# # 1. Problem Statment
#
# Movies lots of metadata about movies.... So actually what is deciding success or failure of movie? That is we only we are going to find out.
# - What is it really that describes their success or failure?
# - Revenu at box office?
# - success or failure association of popular directors or actors?
# - success or failure movie promotion ?
#
# So basically What makes movies good or bad? Here i got opportunity to find few question.
#
# # 2. DataSet Loading and Brif Description
#
# Data set of It contained data from 5043 movies spread across 28 features. The data points included are:
#
#
# |Column Name|Description|
# |---------------------------|---------------------------|
# |movie_title| Contains title of a movie|
# |color| Specifies whether a movie is black and white or color|
# |num_critic_for_reviews| Contains number of critic reviews per movie|
# |movie_facebook_likes| Contains number of facebook likes per movie|
# |duration| Contains duration of a movie in minutes|
# |director_name| Contains name of the director of a movie|
# |director_facebook_likes| Contains number of facebook likes for a director|
# |actor_3_name| Contains the name of the 3rd leading actor of a movie|
# |actor_3_facebook_likes| Contains number of facebook likes for actor 3|
# |actor_2_name| Contains name of 2nd leading actor of a movie|
# |actor_2_facebook_likes| Contains number of facebook likes for actor 2|
# |actor_1_name| Contains name of the actor in lead role|
# |actor_1_facebook_likes| Contains number of facebook likes for actor 1|
# |gross| Contains the amount a movie grossed in USD|
# |genres| Contains the sub-genres to which a movie belongs|
# |num_voted_users| Contains number of users votes for a movie|
# |cast_total_facebook_likes| Contains number of facebook likes for the entire cast of a movie|
# |facenumber_in_poster| Contains number of actor’s faces on a movie poster|
# |plot_keywords| Contains key plot words associated with a movie|
# |movie_imdb_link| Contains the link to the imdb movie page|
# |num_user_for_reviews| Contains the number of user generated reviews per movie|
# |language| Contains the language of a movie|
# |country| Contains the name of the country in which a movie was made|
# |content_rating| Contains maturity rating of a movie|
# |budget| Contains the amount of money spent in production per movie (not always in USD)|
# |title_year| Contains the year in which a film was released|
# |imdb_score| Contains user generated rating per movie|
# |aspect_ratio| Contains the size of the aspect ratio of a movie|
#
#
# ## 2.1 Varaible Note
#
#
#
# ## 2.2 Data Load

# %%
# Importing packges

import numpy as np              # milti-dimensional array and matrices
import pandas as pd             # manipulation and analysis
import pandas_profiling 
import matplotlib.pyplot as plt # umerical mathematics extension NumPy ( Ploting libarary)
import seaborn as sns           # Provides a high level interface for drawing attractive and informative statistical graphics


'''
# %matplotlib inline sets the backend of matplotlib to the 'inline' backend: With this backend, the output of 
plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that
produced it.
'''

# %matplotlib inline

# %%
# we can see the value of multiple statements at once
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
MoviMetaData = pd.read_csv("C://Users//t.shah//Desktop//TanujGit//ExploratoryDataAnalysis-EDA//DataSet/movie_metadata.csv")
MoviMetaData.head()
MoviMetaData.tail()
# Out:
#    color      director_name  num_critic_for_reviews   duration  \
# 0  Color      James Cameron              723.000000 178.000000
# 1  Color     Gore Verbinski              302.000000 169.000000
# 2  Color         Sam Mendes              602.000000 148.000000
# 3  Color  Christopher Nolan              813.000000 164.000000
# 4    NaN        Doug Walker                     nan        nan
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                 0.000000              855.000000  Joel David Moore
# 1               563.000000             1000.000000     Orlando Bloom
# 2                 0.000000              161.000000      Rory Kinnear
# 3             22000.000000            23000.000000    Christian Bale
# 4               131.000000                     nan        Rob Walker
#
#    actor_1_facebook_likes            gross                           genres  \
# 0             1000.000000 760505847.000000  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# # 3.Examining Data Available From An Existing Information Source-Data profiling
#
# ## 3.1 Basic DataSet Understanding

# %%
MoviMetaData.shape
# Out:
# (5043, 28)

# %%
MoviMetaData.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
MoviMetaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %% [markdown]
# #### Observation:
#
#
# - Total row __5043 __ and columns are __28__
# - Most of columns (Values ) has null values.

# %%
total = MoviMetaData.isnull().sum().sort_values(ascending=False)
percent_1 = MoviMetaData.isnull().sum()/MoviMetaData.isnull().count()*100
percent_2 = (round(percent_1, 1))
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.sort_values(by = '%', ascending=True).head(30)
# Out:
# C:\Users\t.shah\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
#                            Total     %
# movie_facebook_likes           0   0.0
# genres                         0   0.0
# movie_imdb_link                0   0.0
# movie_title                    0   0.0
# num_voted_users                0   0.0
# cast_total_facebook_likes      0   0.0
# imdb_score                     0   0.0
# actor_1_facebook_likes         7   0.1
# actor_1_name                   7   0.1
# country                        5   0.1
# language                      12   0.2
# duration                      15   0.3
# facenumber_in_poster          13   0.3
# ...

# %%
pd.set_option('float_format', '{:f}'.format)
pd.set_option('display.max_columns', 100) 
MoviMetaData.describe(include=[np.number]) # have taken only Number Datatypes
# Out:
#        num_critic_for_reviews    duration  director_facebook_likes  \
# count             4949.000000 4983.000000              4895.000000
# mean               139.890079  107.213325               688.679060
# std                121.477586   25.248775              2821.649616
# min                  1.000000    7.000000                 0.000000
# 25%                 50.000000   93.000000                 7.000000
# 50%                110.000000  103.000000                49.000000
# 75%                195.000000  118.000000               192.000000
# max                813.000000  511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes            gross  \
# count             4975.000000             4991.000000      4124.000000
# mean               639.900905             6556.939892  48325648.887488
# std               1643.298282            15061.586700  67964826.775601
# min                  0.000000                0.000000       162.000000
# ...

# %% [markdown]
# ### Observation :
# - The mean, min and max are self-explanatory.
# - std is the standard deviation, which shows how data is dispersed.

# %%
MoviMetaData.select_dtypes(include=['object']).head()
# Out:
#    color      director_name      actor_2_name  \
# 0  Color      James Cameron  Joel David Moore
# 1  Color     Gore Verbinski     Orlando Bloom
# 2  Color         Sam Mendes      Rory Kinnear
# 3  Color  Christopher Nolan    Christian Bale
# 4    NaN        Doug Walker        Rob Walker
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title          actor_3_name  \
# 0                                            Avatar              Wes Studi
# 1          Pirates of the Caribbean: At World's End         Jack Davenport
# 2                                           Spectre       Stephanie Sigman
# ...

# %% [markdown]
# ## 3.2 Pre-Profile

# %%
profile = pandas_profiling.ProfileReport(MoviMetaData)
profile.to_file(outputfile="MoviMetaData_Preprocessing.html")

# %% [markdown]
# ## 3.3 Data Preprocesing Observation
#
# __Details Onservation :__
#
# |Column_Name |Description|Remarks|
# |--------------------------|--------------------------|--------------------------|
# |actor_1_name | High cardinality| 2098 distinct values |
# |actor_2_facebook_likes | 55 / 1.1% zeros Zeros||
# |actor_2_name | High cardinality| 3033 distinct values |
# |actor_3_facebook_likes | 89 / 1.8% zeros Zeros||
# |actor_3_name | High cardinality| 3522 distinct values |
# |aspect_ratio | 329 / 6.5% missing values Missing||
# |budget| is highly skewed (γ1 = 48.157) Skewed||
# |budget | 492 / 9.8% missing values Missing||
# |cast_total_facebook_likes| is highly correlated with actor_1_facebook_likes (ρ = 0.95166)||
# |content_rating | 303 / 6.0% missing values Missing||
# |country | High cardinality| 66 distinct values |
# |director_facebook_likes | 907 / 18.0% zeros Zeros||
# |director_facebook_likes | 104 / 2.1% missing values Missing||
# |director_name | 104 / 2.1% missing values Missing||
# |director_name | High cardinality| 2399 distinct values |
# |facenumber_in_poster | 2152 / 42.7% zeros Zeros||
# |genres | High cardinality| 914 distinct values |
# |gross | 884 / 17.5% missing values Missing||
# |movie_facebook_likes | 2181 / 43.2% zeros Zeros||
# |movie_imdb_link | High cardinality| 4919 distinct values |
# |movie_title | High cardinality| 4917 distinct values |
# |plot_keywords | 153 / 3.0% missing values Missing||
# |plot_keywords | High cardinality| 4761 distinct values |
# |title_year | 108 / 2.1% missing values Missing||
# |Dataset | 45 duplicate rows ||
#
#
# THis notbook we are gone work on :
#
# |Column_Name |description|
# |--------------------------|--------------------------|
# |actor_2_facebook_likes | 55 / 1.1% zeros Zeros|
# |actor_3_facebook_likes | 89 / 1.8% zeros Zeros|
# |aspect_ratio | 329 / 6.5% missing values Missing|
# |budget | 492 / 9.8% missing values Missing|
# |content_rating | 303 / 6.0% missing values Missing|
# |director_facebook_likes | 907 / 18.0% zeros Zeros|
# |director_facebook_likes | 104 / 2.1% missing values Missing|
# |director_name | 104 / 2.1% missing values Missing|
# |facenumber_in_poster | 2152 / 42.7% zeros Zeros|
# |gross | 884 / 17.5% missing values Missing|
# |movie_facebook_likes | 2181 / 43.2% zeros Zeros|
# |plot_keywords | 153 / 3.0% missing values Missing|
# |title_year | 108 / 2.1% missing values Missing|
# |Dataset | 45 duplicate rows |

# %% [markdown]
# ## 3.3 Working on Pre-Proessing Observation
#
# ### 3.3.1 Drop Duplicates Records
# Removing the duplicacy in the rows (if any):

# %%
MoviMetaData = MoviMetaData.drop_duplicates()

# %%
MoviMetaData[MoviMetaData['movie_title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []

# %%
MoviMetaData[MoviMetaData['movie_title'] .isnull()]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []

# %% [markdown]
# ### 3.3.1 Title Year Replace with Median

# %%
Median_Year = MoviMetaData.title_year.median()
MoviMetaData.title_year.fillna(Median_Year, inplace = True)

# %%
MoviMetaData[MoviMetaData['title_year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []

# %% [markdown]
# ### 3.3.3  Working on Genres

# %%
MoviMetaData['title_year'] = MoviMetaData['title_year'].astype(int)

# %%
import itertools
unique_Genre = MoviMetaData['genres'].unique()
individual_genres = []
for genre in unique_Genre:
    individual_genres.append(genre.split('|'))
    
individual_genres = list(itertools.chain.from_iterable(individual_genres))
individual_genres = set(individual_genres)

individual_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
print('Number of movies in each genre: \n')

for genre in individual_genres:
    current_genre = MoviMetaData['genres'].str.contains(genre).fillna(False)
    plt.figure()
    plt.xlabel('Year')
    plt.ylabel('Number of Movies Made')
    plt.title(str(genre))
    MoviMetaData[current_genre].title_year.value_counts().sort_index().plot(kind='bar', color='r', alpha=0.5, rot=45)
    print(genre, len(MoviMetaData[current_genre]))
# Out:
# Number of movies in each genre:
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'War')
# War 211
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Animation')
# Animation 242
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Short')
# Short 5
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'History')
# History 205
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Thriller')
# Thriller 1396
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Western')
# Western 94
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Game-Show')
# Game-Show 1
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Documentary')
# Documentary 121
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Action')
# Action 1143
# Text(0.5,0,'Year')
# Text(0,0.5,'Number of Movies Made')
# Text(0.5,1,'Mystery')
# ...

# %% [markdown]
# ### 3.3.4  creating a new feature called total_facebook_likes

# %%
MoviMetaData.head()
# Out:
#    color      director_name  num_critic_for_reviews   duration  \
# 0  Color      James Cameron              723.000000 178.000000
# 1  Color     Gore Verbinski              302.000000 169.000000
# 2  Color         Sam Mendes              602.000000 148.000000
# 3  Color  Christopher Nolan              813.000000 164.000000
# 4    NaN        Doug Walker                     nan        nan
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        1                       1  Joel David Moore
# 1                        1                       1     Orlando Bloom
# 2                        1                       1      Rory Kinnear
# 3                        1                       1    Christian Bale
# 4                        1                       0        Rob Walker
#
#    actor_1_facebook_likes            gross                           genres  \
# 0                       1 760505847.000000  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
MoviMetaData['total_facebook_likes']= MoviMetaData['director_facebook_likes'] + MoviMetaData['actor_3_facebook_likes'] + MoviMetaData['actor_1_facebook_likes'] + MoviMetaData['cast_total_facebook_likes'] +  MoviMetaData['actor_2_facebook_likes'] +  MoviMetaData['movie_facebook_likes']
MoviMetaData.head()
# Out:
#    color      director_name  num_critic_for_reviews   duration  \
# 0  Color      James Cameron              723.000000 178.000000
# 1  Color     Gore Verbinski              302.000000 169.000000
# 2  Color         Sam Mendes              602.000000 148.000000
# 3  Color  Christopher Nolan              813.000000 164.000000
# 4    NaN        Doug Walker                     nan        nan
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                 0.000000              855.000000  Joel David Moore
# 1               563.000000             1000.000000     Orlando Bloom
# 2                 0.000000              161.000000      Rory Kinnear
# 3             22000.000000            23000.000000    Christian Bale
# 4               131.000000                     nan        Rob Walker
#
#    actor_1_facebook_likes            gross                           genres  \
# 0             1000.000000 760505847.000000  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
x = MoviMetaData['imdb_score']
sns.distplot(x, bins=10);

# %%
ax = sns.catplot(x="imdb_score", kind="count" ,orient='h', data=MoviMetaData,);

# %%
https://www.kaggle.com/karrrimba/understanding-movies-through-data

# %% [markdown]
# ### 3.3.5 creating feature return_on_investment

# %%
MoviMetaData['Retrun_on_investement'] = (MoviMetaData['gross']  - MoviMetaData['budget'])/MoviMetaData['budget']

# %%
MoviMetaData['profit_loss'] = MoviMetaData.apply(lambda x: 1 if x['Retrun_on_investement'] > 0  else 0,axis=1)
# 1 is Profit
# 0 is loos/No profit no loss

# %%
MoviMetaData
# Out:
#    color      director_name  num_critic_for_reviews   duration  \
# 0  Color      James Cameron              723.000000 178.000000
# 1  Color     Gore Verbinski              302.000000 169.000000
# 2  Color         Sam Mendes              602.000000 148.000000
# 3  Color  Christopher Nolan              813.000000 164.000000
# 4    NaN        Doug Walker                     nan        nan
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                 0.000000              855.000000  Joel David Moore
# 1               563.000000             1000.000000     Orlando Bloom
# 2                 0.000000              161.000000      Rory Kinnear
# 3             22000.000000            23000.000000    Christian Bale
# 4               131.000000                     nan        Rob Walker
#
#    actor_1_facebook_likes            gross                           genres  \
# 0             1000.000000 760505847.000000  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
budget_null = MoviMetaData[MoviMetaData['budget'].isnull()]
sns.jointplot(x="x", y="y", data=budget_null);
